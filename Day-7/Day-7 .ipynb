# %% [markdown]
# ## Today's Concepts
#
# - pandas
#  - Dataframe is a multiple rows and multiple columns

# %%
import pandas as pd
import numpy as np

# %%
# creating a dataframe
df = pd.DataFrame([[1,2],[3,4]])

# %%
df
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
df = pd.DataFrame({'ravi':[1,2,3,4,5],'alekhya':[6,7,8,9,10]})

# %%
df
# Out:
#    ravi  alekhya
# 0     1        6
# 1     2        7
# 2     3        8
# 3     4        9
# 4     5       10

# %%
df = pd.DataFrame({'ravi':[70,60,80,98,75],'alekhya':[80,68,76,87,99],'anil':[50,70,100,75,90]})

# %%
df
# Out:
#    ravi  alekhya  anil
# 0    70       80    50
# 1    60       68    70
# 2    80       76   100
# 3    98       87    75
# 4    75       99    90

# %%
df.index = ['python','django','machinelearning','dataanalysis','deeplearning']

# %%
df
# Out:
#                  ravi  alekhya  anil
# python             70       80    50
# django             60       68    70
# machinelearning    80       76   100
# dataanalysis       98       87    75
# deeplearning       75       99    90

# %%
df.loc['python']
# Out:
# ravi       70
# alekhya    80
# anil       50
# Name: python, dtype: int64

# %%
df.loc['deeplearning']
# Out:
# ravi       75
# alekhya    99
# anil       90
# Name: deeplearning, dtype: int64

# %%
df.loc['machinelearning']
# Out:
# ravi        80
# alekhya     76
# anil       100
# Name: machinelearning, dtype: int64

# %%
df.iloc[0:3]
# Out:
#                  ravi  alekhya  anil
# python             70       80    50
# django             60       68    70
# machinelearning    80       76   100

# %%
df
# Out:
#                  ravi  alekhya  anil
# python             70       80    50
# django             60       68    70
# machinelearning    80       76   100
# dataanalysis       98       87    75
# deeplearning       75       99    90

# %%
df.iloc[2:3,1:2]
# Out:
#                  alekhya
# machinelearning       76

# %%
df
# Out:
#                  ravi  alekhya  anil
# python             70       80    50
# django             60       68    70
# machinelearning    80       76   100
# dataanalysis       98       87    75
# deeplearning       75       99    90

# %%
df.iloc[1:4:2,1:3]
# Out:
#               alekhya  anil
# django             68    70
# dataanalysis       87    75

# %%
data = {'rollnumber':['678282gg5'+str(i) for i in range(1,101)],'python':np.random.randint(1,100,100),'ml':np.random.randint(1,100,100),'django':np.random.randint(1,100,100),'deeplearning':np.random.randint(1,100,100)}
data
# Out:
# {'rollnumber': ['678282gg51',
#   '678282gg52',
#   '678282gg53',
#   '678282gg54',
#   '678282gg55',
#   '678282gg56',
#   '678282gg57',
#   '678282gg58',
#   '678282gg59',
#   '678282gg510',
#   '678282gg511',
#   '678282gg512',
#   '678282gg513',
#   '678282gg514',
#   '678282gg515',
#   '678282gg516',
#   '678282gg517',
#   '678282gg518',
#   '678282gg519',
#   '678282gg520',
#   '678282gg521',
#   '678282gg522',
#   '678282gg523',
#   '678282gg524',
#   '678282gg525',
#   '678282gg526',
#   '678282gg527',
#   '678282gg528',
#   '678282gg529',
#   '678282gg530',
#   '678282gg531',
#   '678282gg532',
#   '678282gg533',
#   '678282gg534',
#   '678282gg535',
#   '678282gg536',
#   '678282gg537',
#   '678282gg538',
#   '678282gg539',
#   '678282gg540',
#   '678282gg541',
#   '678282gg542',
#   '678282gg543',
#   '678282gg544',
#   '678282gg545',
#   '678282gg546',
#   '678282gg547',
#   '678282gg548',
#   '678282gg549',
#   '678282gg550',
#   '678282gg551',
#   '678282gg552',
# ...

# %%
df = pd.DataFrame(data,index=[np.arange(1,101)])
df
# Out:
#        rollnumber  python  ml  django  deeplearning
# 1      678282gg51      19  85      66            59
# 2      678282gg52      17  83      23            92
# 3      678282gg53      15  70      72            62
# 4      678282gg54      58  33      56            69
# 5      678282gg55      28  20      61            80
# ..            ...     ...  ..     ...           ...
# 96    678282gg596      92  70      74            34
# 97    678282gg597      68  60      66            64
# 98    678282gg598      76  87      81            13
# 99    678282gg599       8  69      99             4
# 100  678282gg5100      32  87      79            26
#
# [100 rows x 5 columns]

# %%
df.head()
# Out:
#    rollnumber  python  ml  django  deeplearning
# 1  678282gg51      19  85      66            59
# 2  678282gg52      17  83      23            92
# 3  678282gg53      15  70      72            62
# 4  678282gg54      58  33      56            69
# 5  678282gg55      28  20      61            80

# %%
df.tail()
# Out:
#        rollnumber  python  ml  django  deeplearning
# 96    678282gg596      92  70      74            34
# 97    678282gg597      68  60      66            64
# 98    678282gg598      76  87      81            13
# 99    678282gg599       8  69      99             4
# 100  678282gg5100      32  87      79            26

# %%
df.sample(2)
# Out:
#      rollnumber  python  ml  django  deeplearning
# 24  678282gg524      76   8      94            78
# 70  678282gg570      37  73      35            58

# %%
df['python'].head()
# Out:
# 1    19
# 2    17
# 3    15
# 4    58
# 5    28
# Name: python, dtype: int32

# %%
df[['rollnumber','python','ml']].head()
# Out:
#    rollnumber  python  ml
# 1  678282gg51      19  85
# 2  678282gg52      17  83
# 3  678282gg53      15  70
# 4  678282gg54      58  33
# 5  678282gg55      28  20

# %%
df.iloc[50]
# Out:
# rollnumber      678282gg551
# python                   88
# ml                       72
# django                   67
# deeplearning             14
# Name: (51,), dtype: object

# %%
df.iloc[50:60][['rollnumber','python','ml']]
# Out:
#      rollnumber  python  ml
# 51  678282gg551      88  72
# 52  678282gg552      76   1
# 53  678282gg553      89  62
# 54  678282gg554      38   3
# 55  678282gg555      95  84
# 56  678282gg556      77  66
# 57  678282gg557       2  70
# 58  678282gg558      75   6
# 59  678282gg559      83  29
# 60  678282gg560      39  57

# %%
df.iloc[0:100:2,0:3]
# Out:
#      rollnumber  python  ml
# 1    678282gg51      19  85
# 3    678282gg53      15  70
# 5    678282gg55      28  20
# 7    678282gg57       6  63
# 9    678282gg59      32  86
# 11  678282gg511      42  76
# 13  678282gg513       4  77
# 15  678282gg515       9  10
# 17  678282gg517      68  85
# 19  678282gg519       6  41
# 21  678282gg521      98  30
# 23  678282gg523      22  67
# 25  678282gg525      10  89
# 27  678282gg527      87  93
# 29  678282gg529       6  11
# 31  678282gg531       4  20
# 33  678282gg533      94  91
# 35  678282gg535      17  95
# 37  678282gg537      55  91
# 39  678282gg539      23   2
# 41  678282gg541      31   3
# 43  678282gg543      80  79
# 45  678282gg545      21   4
# 47  678282gg547      92  96
# 49  678282gg549      96  52
# 51  678282gg551      88  72
# 53  678282gg553      89  62
# 55  678282gg555      95  84
# 57  678282gg557       2  70
# 59  678282gg559      83  29
# 61  678282gg561      12  13
# 63  678282gg563      42  45
# ...

# %%
df.iloc[0:100:2,0:5:2]
# Out:
#      rollnumber  ml  deeplearning
# 1    678282gg51  85            59
# 3    678282gg53  70            62
# 5    678282gg55  20            80
# 7    678282gg57  63            95
# 9    678282gg59  86            92
# 11  678282gg511  76            59
# 13  678282gg513  77            24
# 15  678282gg515  10            84
# 17  678282gg517  85            87
# 19  678282gg519  41            57
# 21  678282gg521  30            61
# 23  678282gg523  67            84
# 25  678282gg525  89            36
# 27  678282gg527  93            93
# 29  678282gg529  11            17
# 31  678282gg531  20            77
# 33  678282gg533  91            39
# 35  678282gg535  95            69
# 37  678282gg537  91            20
# 39  678282gg539   2             4
# 41  678282gg541   3             6
# 43  678282gg543  79            17
# 45  678282gg545   4             7
# 47  678282gg547  96             2
# 49  678282gg549  52            57
# 51  678282gg551  72            14
# ...

# %%
df.isna().sum()
# Out:
# rollnumber      0
# python          0
# ml              0
# django          0
# deeplearning    0
# dtype: int64

# %%
data = {'ravi':[40,50,np.nan,60,70],'anil':[70,np.nan,60,np.nan,80]}
df = pd.DataFrame(data,index = [1,2,3,4,5])

# %%
df
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0   NaN
# 3   NaN  60.0
# 4  60.0   NaN
# 5  70.0  80.0

# %%
df.isnull().sum()
# Out:
# ravi    1
# anil    2
# dtype: int64

# %%
df.fillna(70)
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0  70.0
# 3  70.0  60.0
# 4  60.0  70.0
# 5  70.0  80.0

# %%
df['ravi'].fillna(70)
# Out:
# 1    40.0
# 2    50.0
# 3    70.0
# 4    60.0
# 5    70.0
# Name: ravi, dtype: float64

# %%
df.dropna()
# Out:
#    ravi  anil
# 1  40.0  70.0
# 5  70.0  80.0

# %%
df.fillna(method='ffill')
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0  70.0
# 3  50.0  60.0
# 4  60.0  60.0
# 5  70.0  80.0

# %%
df.fillna(method = 'bfill')
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0  60.0
# 3  60.0  60.0
# 4  60.0  80.0
# 5  70.0  80.0

# %%
df
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0   NaN
# 3   NaN  60.0
# 4  60.0   NaN
# 5  70.0  80.0

# %%
df['ravi'].fillna(method='ffill',inplace=True)

# %%
df.isna().sum()
# Out:
# ravi    0
# anil    2
# dtype: int64

# %%
df.fillna(method = 'ffill',inplace=True)

# %%
df
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0  70.0
# 3  50.0  60.0
# 4  60.0  60.0
# 5  70.0  80.0

# %%
data = {'ravi':[40,50,np.nan,60,70],'anil':[70,np.nan,60,np.nan,80]}
df = pd.DataFrame(data,index = [1,2,3,4,5])

# %%
df.mean()
# Out:
# ravi    55.0
# anil    70.0
# dtype: float64

# %%
df.max()
# Out:
# ravi    70.0
# anil    80.0
# dtype: float64

# %%
df.min()
# Out:
# ravi    40.0
# anil    60.0
# dtype: float64

# %%
df.std()
# Out:
# ravi    12.909944
# anil    10.000000
# dtype: float64

# %%
df.median()
# Out:
# ravi    55.0
# anil    70.0
# dtype: float64

# %%
df.idxmax()
# Out:
# ravi    5
# anil    5
# dtype: int64

# %%
df.idxmin()
# Out:
# ravi    1
# anil    3
# dtype: int64

# %%
df
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0   NaN
# 3   NaN  60.0
# 4  60.0   NaN
# 5  70.0  80.0

# %%
df['ravi'].fillna(df['ravi'].mean(),inplace = True)

# %%
df['anil'].fillna(df['anil'].mean(),inplace = True)

# %%
df
# Out:
#    ravi  anil
# 1  40.0  70.0
# 2  50.0  70.0
# 3  55.0  60.0
# 4  60.0  70.0
# 5  70.0  80.0
